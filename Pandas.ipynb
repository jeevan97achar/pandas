# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Github/
# Out:
# /content/drive/MyDrive/Github

# %%
# !git init Pandas
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Github/Pandas/.git/

# %%
# %cd Pandas/
# Out:
# /content/drive/MyDrive/Github/Pandas

# %%
username = 'jeevan97achar'
git_token = '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'
repository = 'pandas'

# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git
# !git remote set-url origin https://{git_token}@github.com/{username}/{repository}.git
